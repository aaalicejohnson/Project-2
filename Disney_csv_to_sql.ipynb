# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import inspect
import config

from config import user
from config import admin

# %%
disney_file = "Resources/Disney_Movies.csv"
disney_df = pd.read_csv(disney_file)
disney_df.head(2)
# Out:
#    Unnamed: 0                                             title  \
# 0           0  Duck the Halls: A Mickey Mouse Christmas Special
# 1           1                            Ernest Saves Christmas
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
#
#                                                 cast country  release_year
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...     NaN          2016
# 1           Jim Varney, Noelle Parker, Douglas Seale     NaN          1988

# %%
c_disney_df = disney_df.drop(columns=["Unnamed: 0"])

# %%
c_disney_df = c_disney_df.rename(columns={"cast": "movie_cast"})

# %%
c_disney_df['id'] = c_disney_df.index
c_disney_df.head()
# Out:
#                                               title  \
# 0  Duck the Halls: A Mickey Mouse Christmas Special
# 1                            Ernest Saves Christmas
# 2                      Ice Age: A Mammoth Christmas
# 3                        The Queen Family Singalong
# 4                                 Becoming Cousteau
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                         Liz Garbus
#
#                                           movie_cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...            NaN
# 4              Jacques Yves Cousteau, Vincent Cassel  United States
#
# ...

# %%
protocol = 'postgresql'
username = user
password = admin
host = 'localhost'
port = 5432
database_name = 'movies'

rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
        
engine = create_engine(rds_connection_string)

# %%
inspector = inspect(engine)

inspector.get_table_names()
# Out:
# ['netflix', 'disney_plus']

# %%
c_disney_df.to_sql(name='disney_plus', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from disney_plus', con=engine).head()
# Out:
#    id                                             title  \
# 0   0  Duck the Halls: A Mickey Mouse Christmas Special
# 1   1                            Ernest Saves Christmas
# 2   2                      Ice Age: A Mammoth Christmas
# 3   3                        The Queen Family Singalong
# 4   4                                 Becoming Cousteau
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                         Liz Garbus
#
#                                           movie_cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...           None
# 1           Jim Varney, Noelle Parker, Douglas Seale           None
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...           None
# ...
