# %%
#Dependencies
import pandas as pd
import requests
import json
from json.decoder import JSONDecodeError
from config import api_key
from pprint import pprint

# %%
# Read csv file
netflix_file = "../Resources/Netflix_Movies.csv"
netflix_df = pd.read_csv(netflix_file,index_col=0)
# making a copy with 'title'
movies_df= netflix_df[['title']].copy()
movies_df.head()
# Out:
#                               title
# 0              Dick Johnson Is Dead
# 1  My Little Pony: A New Generation
# 2                           Sankofa
# 3                      The Starling
# 4                      Je Suis Karl

# %%
# create new columns
movies_df["budget"]=''
movies_df["revenue"]=''
movies_df["runtime"]=''
movies_df["movie_id"]=''
movies_df["genre"]=''


# take first 3131 records process and fetch API data,create a csv for first 3131 records
# movie_df=movies_df.head(3131)

#take next 3000 records process and fetcg API data,create a csv for the next 3000 records
movie_df=movies_df.tail(3000)
movie_df
# Out:
#                                          title budget revenue runtime  \
# 3131                   CIA: Comrade in America
# 3132                            Coffee for All
# 3133                                      Darc
# 3134                        Despido Procedente
# 3135  John Mulaney: Kid Gorgeous at Radio City
# ...                                        ...    ...     ...     ...
# 6126                                   Zinzana
# 6127                                    Zodiac
# 6128                                Zombieland
# 6129                                      Zoom
# 6130                                    Zubaan
#
#      movie_id genre
# 3131
# 3132
# 3133
# 3134
# 3135
# ...       ...   ...
# 6126
# 6127
# 6128
# 6129
# 6130
#
# [3000 rows x 6 columns]

# %%
# loop through the sample dataframe
for index,row in movie_df.iterrows():
# pass the movie title from the dataframe,fetch the movie id from the API
    movie_title=row['title']
    url = f"https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={movie_title}"
    try:
        print(index)
        response = requests.get(url).json()
        movie_df.loc[index,'movie_id']=response['results'][0]['id']
    except (KeyError, IndexError, JSONDecodeError):
        print("Data not found... skipping.")
    except requests.ConnectionError:
        print("ConnectionError...")
# Out:
# 3131
# C:\Users\13135\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 3132
# 3133
# 3134
# 3135
# 3136
# 3137
# 3138
# 3139
# Data not found... skipping.
# 3140
# Data not found... skipping.
# 3141
# Data not found... skipping.
# 3142
# 3143
# 3144
# 3145
# 3146
# 3147
# 3148
# 3149
# 3150
# 3151
# 3152
# 3153
# 3154
# 3155
# 3156
# 3157
# 3158
# 3159
# 3160
# 3161
# 3162
# 3163
# 3164
# 3165
# 3166
# 3167
# 3168
# 3169
# 3170
# 3171
# 3172
# 3173
# 3174
# 3175
# 3176
# 3177
# 3178
# 3179
# 3180
# 3181
# 3182
# 3183
# 3184
# 3185
# 3186
# 3187
# 3188
# 3189
# 3190
# 3191
# 3192
# 3193
# 3194
# 3195
# 3196
# 3197
# 3198
# 3199
# 3200
# 3201
# 3202
# 3203
# 3204
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# ...

# %%
# loop through the sample dataframe
for index,row in movie_df.iterrows():
# pass the movie id and fetch the response from the API
        movie_id=row['movie_id']
        url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}&language=en-US"
        try:
            print(index)
            response_id = requests.get(url).json()
            movie_df.loc[index,'budget']=response_id['budget']
            movie_df.loc[index,'revenue']=response_id['revenue']
            movie_df.loc[index,'runtime']=response_id['runtime']
            genre_type_list = response_id['genres'] 
            genre_type_str=""
            if genre_type_list != None :
                for genre_type in genre_type_list:
                    genre_type_str += genre_type['name']+","
            else:
                genre_type_str = "NA"
            movie_df.loc[index,"genre"]=genre_type_str 
    #         movie_id_list.append(movie_id)
        except (KeyError, IndexError, JSONDecodeError):
            print("Data not found... skipping.")
        except requests.ConnectionError:
            print("ConnectionError...")
# Out:
# 3131
# C:\Users\13135\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\13135\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\13135\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# write the first 3131 and last 3000 in separate csv
# movie_df.to_csv('sample_head.csv')
movie_df.to_csv('sample_tail.csv')

# %%
# read csv file
movies_head = pd.read_csv('sample_head.csv',index_col=0)
movies_tail = pd.read_csv('sample_tail.csv',index_col=0)

# %%
movies_head
# Out:
#                                            title     budget    revenue  \
# 0                           Dick Johnson Is Dead        0.0        0.0
# 1               My Little Pony: A New Generation        0.0  4100000.0
# 2                                        Sankofa  1000000.0  2691899.0
# 3                                   The Starling        0.0        0.0
# 4                                   Je Suis Karl        0.0        0.0
# ...                                          ...        ...        ...
# 3126                                     Manhunt        0.0        0.0
# 3127                                     Thi Mai        0.0        0.0
# 3128  Si saben cómo me pongo ¿pá qué me invitan?        0.0        0.0
# 3129                                   Jailbreak        0.0        0.0
# 3130                                        Ajji        0.0        0.0
#
#       runtime  movie_id                                       genre
# ...

# %%
movies_tail
# Out:
#                                          title      budget      revenue  \
# 3131                   CIA: Comrade in America   1400000.0    3900000.0
# 3132                            Coffee for All         0.0          0.0
# 3133                                      Darc         0.0          0.0
# 3134                        Despido Procedente         0.0          0.0
# 3135  John Mulaney: Kid Gorgeous at Radio City         0.0          0.0
# ...                                        ...         ...          ...
# 6126                                   Zinzana         0.0          0.0
# 6127                                    Zodiac  65000000.0   84785914.0
# 6128                                Zombieland  23600000.0  102391540.0
# 6129                                      Zoom  75600000.0   12506188.0
# 6130                                    Zubaan         0.0          0.0
#
#       runtime  movie_id                                            genre
# ...

# %%
# concatenate into one dataframe
combined_df = pd.concat([movies_head,movies_tail], axis=0)
combined_df['streaming']='Netflix'
combined_df
# Out:
#                                  title      budget      revenue  runtime  \
# 0                 Dick Johnson Is Dead         0.0          0.0     89.0
# 1     My Little Pony: A New Generation         0.0    4100000.0     91.0
# 2                              Sankofa   1000000.0    2691899.0    124.0
# 3                         The Starling         0.0          0.0    103.0
# 4                         Je Suis Karl         0.0          0.0    126.0
# ...                                ...         ...          ...      ...
# 6126                           Zinzana         0.0          0.0     96.0
# 6127                            Zodiac  65000000.0   84785914.0    157.0
# 6128                        Zombieland  23600000.0  102391540.0     88.0
# 6129                              Zoom  75600000.0   12506188.0     83.0
# 6130                            Zubaan         0.0          0.0    118.0
#
#       movie_id                                            genre streaming
# ...

# %%
# merging the data from netflix and API
final_df = pd.merge(netflix_df,combined_df,on='title')
final_df
# Out:
#                                  title                       director  \
# 0                 Dick Johnson Is Dead                Kirsten Johnson
# 1     My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 2                              Sankofa                   Haile Gerima
# 3                         The Starling                 Theodore Melfi
# 4                         Je Suis Karl            Christian Schwochow
# ...                                ...                            ...
# 6126                           Zinzana                Majid Al Ansari
# 6127                            Zodiac                  David Fincher
# 6128                        Zombieland                Ruben Fleischer
# 6129                              Zoom                   Peter Hewitt
# 6130                            Zubaan                    Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# ...

# %%
# save to csv
final_df.to_csv('netflix_API_list.csv')
